# %%
import numpy as np
import pandas as pd

# %%
input=pd.read_csv('input.csv')
input.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
train=input[:385049]
test=input[385049:]
train.info()
test.info()
train.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday3070\train.csv',index=False)
test.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday3070\test.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385049 entries, 0 to 385048
# Data columns (total 12 columns):
# User_ID                       385049 non-null int64
# Product_ID                    385049 non-null object
# Gender                        385049 non-null object
# Age                           385049 non-null object
# Occupation                    385049 non-null int64
# City_Category                 385049 non-null object
# Stay_In_Current_City_Years    385049 non-null object
# Marital_Status                385049 non-null int64
# Product_Category_1            385049 non-null int64
# Product_Category_2            265619 non-null float64
# Product_Category_3            117819 non-null float64
# Purchase                      385049 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 35.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165019 entries, 385049 to 550067
# Data columns (total 12 columns):
# User_ID                       165019 non-null int64
# Product_ID                    165019 non-null object
# Gender                        165019 non-null object
# Age                           165019 non-null object
# Occupation                    165019 non-null int64
# City_Category                 165019 non-null object
# Stay_In_Current_City_Years    165019 non-null object
# Marital_Status                165019 non-null int64
# Product_Category_1            165019 non-null int64
# Product_Category_2            110811 non-null float64
# Product_Category_3            49002 non-null float64
# Purchase                      165019 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 15.1+ MB

# %%
submission=input.loc[385049:,['User_ID','Product_ID','Purchase']]

# %%
submission.head()
submission.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday3070\submission.csv',index=False)

# %%
test.head()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 385049  1005266  P00031042      M  36-45           1             C
# 385050  1005267  P00295842      M  36-45           7             C
# 385051  1005267   P0096442      M  36-45           7             C
# 385052  1005269  P00274942      M  18-25           0             B
# 385053  1005269  P00275842      M  18-25           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 385049                          1               0                   8
# 385050                          2               0                   5
# 385051                          2               0                   4
# 385052                         4+               0                   8
# 385053                         4+               0                   2
#
#         Product_Category_2  Product_Category_3  Purchase
# 385049                 NaN                 NaN      9722
# 385050                 8.0                 NaN      5330
# 385051                 5.0                12.0      3501
# 385052                 NaN                 NaN      9988
# 385053                 9.0                15.0     16166

# %%
del(test['Purchase'])

# %%
test.head()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 385049  1005266  P00031042      M  36-45           1             C
# 385050  1005267  P00295842      M  36-45           7             C
# 385051  1005267   P0096442      M  36-45           7             C
# 385052  1005269  P00274942      M  18-25           0             B
# 385053  1005269  P00275842      M  18-25           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 385049                          1               0                   8
# 385050                          2               0                   5
# 385051                          2               0                   4
# 385052                         4+               0                   8
# 385053                         4+               0                   2
#
#         Product_Category_2  Product_Category_3
# 385049                 NaN                 NaN
# 385050                 8.0                 NaN
# 385051                 5.0                12.0
# 385052                 NaN                 NaN
# 385053                 9.0                15.0

# %%
test.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday3070\test.csv',index=False)

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
import seaborn as sns
sns.pairplot(train.dropna(),hue='Gender')

# %%
sns.pairplot(train.dropna(),hue='Age')

# %%
sns.pairplot(train.dropna())

# %%
frames=[train,test]
input=pd.concat(frames)
input.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday3070\input_total.csv',index=False)
print (input.shape)
input.head()
# Out:
# (550068, 12)
#     Age City_Category Gender  Marital_Status  Occupation  Product_Category_1  \
# 0  0-17             A      F               0          10                   3
# 1  0-17             A      F               0          10                   1
# 2  0-17             A      F               0          10                  12
# 3  0-17             A      F               0          10                  12
# 4   55+             C      M               0          16                   8
#
#    Product_Category_2  Product_Category_3 Product_ID  Purchase  \
# 0                 NaN                 NaN  P00069042    8370.0
# 1                 6.0                14.0  P00248942   15200.0
# 2                 NaN                 NaN  P00087842    1422.0
# 3                14.0                 NaN  P00085442    1057.0
# 4                 NaN                 NaN  P00285442    7969.0
#
#   Stay_In_Current_City_Years  User_ID
# 0                          2  1000001
# 1                          2  1000001
# 2                          2  1000001
# 3                          2  1000001
# 4                         4+  1000002

# %%
input.dtypes
# Out:
# Age                            object
# City_Category                  object
# Gender                         object
# Marital_Status                  int64
# Occupation                      int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Product_ID                     object
# Purchase                      float64
# Stay_In_Current_City_Years     object
# User_ID                         int64
# dtype: object

# %%
input.fillna(999,inplace=True)
input.head()
# Out:
#     Age City_Category Gender  Marital_Status  Occupation  Product_Category_1  \
# 0  0-17             A      F               0          10                   3
# 1  0-17             A      F               0          10                   1
# 2  0-17             A      F               0          10                  12
# 3  0-17             A      F               0          10                  12
# 4   55+             C      M               0          16                   8
#
#    Product_Category_2  Product_Category_3 Product_ID  Purchase  \
# 0               999.0               999.0  P00069042    8370.0
# 1                 6.0                14.0  P00248942   15200.0
# 2               999.0               999.0  P00087842    1422.0
# 3                14.0               999.0  P00085442    1057.0
# 4               999.0               999.0  P00285442    7969.0
#
#   Stay_In_Current_City_Years  User_ID
# 0                          2  1000001
# 1                          2  1000001
# 2                          2  1000001
# 3                          2  1000001
# 4                         4+  1000002

# %%
target=input.Purchase
target=np.array(target)
input.drop(['Purchase'],axis=1,inplace=True)

# %%
print(input.columns,input.dtypes)
# Out:
# Index(['Age', 'City_Category', 'Gender', 'Marital_Status', 'Occupation',
#        'Product_Category_1', 'Product_Category_2', 'Product_Category_3',
#        'Product_ID', 'Stay_In_Current_City_Years', 'User_ID'],
#       dtype='object') Age                            object
# City_Category                  object
# Gender                         object
# Marital_Status                  int64
# Occupation                      int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Product_ID                     object
# Stay_In_Current_City_Years     object
# User_ID                         int64
# dtype: object

# %%
input=input.applymap(str)
input.dtypes
# Out:
# Age                           object
# City_Category                 object
# Gender                        object
# Marital_Status                object
# Occupation                    object
# Product_Category_1            object
# Product_Category_2            object
# Product_Category_3            object
# Product_ID                    object
# Stay_In_Current_City_Years    object
# User_ID                       object
# dtype: object

# %%
input_pd=input.copy()

# %%
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer


from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn import linear_model

from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
input=np.array(input)

for i in range(input.shape[1]):
    lbl=preprocessing.LabelEncoder()
    lbl.fit(list(input[:,i]))
    input[:,i]=lbl.transform(input[:,i])

# %%
print(input[4])
input=input.astype(int)
# Out:
# [6 2 1 0 8 18 17 15 2734 4 1]

# %%
#xgboost model
import xgboost as xgb
params={}
params['min_child_weight']=10
params['subsample']=0.7
params['colsample_bytree']=0.7
params['scale_pos_weight']=0.8
params['silent']=1                                                                                                                                        
params['max_depth']=6
params['nthread']=6
params['objective']='reg:linear'
params['eta']=0.1
params['base_score']=1800
params['eval_metric']='rmse'
params['seed']=0
plst=list(params.items())
num_rounds=300

# %%
import matplotlib.pyplot as plt
from xgboost import XGBClassifier, plot_importance
xgtrain=xgb.DMatrix(input[:train.shape[0],:],label=target[:train.shape[0]])
watchlist=[(xgtrain,'train')]
model_1_xgboost=xgb.train(plst,xgtrain,num_rounds)
plot_importance(model_1_xgboost)
plt.show()
'''print(model_1_xgboost.feature_importances_)
plt.bar(range(len(model_1_xgboost.feature_importances_)),model_1_xgboost.feature_importances_)
plt.show()'''
model_1_xgboost.get_score(importance_type='gain')
# Out:
# {'f0': 94880647.29152824,
#  'f1': 177820839.96666667,
#  'f10': 145338244.71123376,
#  'f2': 79826898.11328976,
#  'f3': 59943963.454301074,
#  'f4': 83115546.52774353,
#  'f5': 11950581016.86775,
#  'f6': 1045636457.0761495,
#  'f7': 2050991918.4542587,
#  'f8': 706737475.5845486,
#  'f9': 84552668.56644738}

# %%
import pickle
pickle.dump(model_1_xgboost, open("model_1_xgboost.pickle.dat", "wb"))

# %%
model_1_predict=model_1_xgboost.predict(xgb.DMatrix(input[train.shape[0]:,:]))
model_1_predict[model_1_predict<0]=25
submission.Purchase=model_1_predict
#submission.to_csv('../submission/submit_13.csv',index=False)
submission.to_csv(r'C:/Users/sk/AnacondaProjects/blackfriday3070/first_model.csv',index=False)
early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8221.73+2.62906	test-rmse:8221.81+11.1236
# [1]	train-rmse:7577.87+58.7066	test-rmse:7577.78+49.6866
# [2]	train-rmse:7005.82+71.896	test-rmse:7006.03+64.9199
# [3]	train-rmse:6476.81+95.0052	test-rmse:6477.26+89.439
# [4]	train-rmse:6011.29+112.221	test-rmse:6011.89+110.143
# [5]	train-rmse:5594.79+101.945	test-rmse:5595.47+104.368
# [6]	train-rmse:5210.97+79.1133	test-rmse:5211.77+78.9398
# [7]	train-rmse:4877.86+82.775	test-rmse:4878.56+83.381
# [8]	train-rmse:4595.64+54.1301	test-rmse:4596.48+52.5598
# [9]	train-rmse:4329.04+47.6176	test-rmse:4330.04+46.6736
# [10]	train-rmse:4118.55+45.8936	test-rmse:4119.94+38.9496
# [11]	train-rmse:3930.18+50.1471	test-rmse:3931.69+46.506
# [12]	train-rmse:3767.89+49.2657	test-rmse:3769.85+41.5496
# [13]	train-rmse:3636.69+45.0348	test-rmse:3638.89+41.5196
# [14]	train-rmse:3510.02+38.4239	test-rmse:3512.54+35.6652
# [15]	train-rmse:3419.27+31.9741	test-rmse:3421.93+27.5781
# [16]	train-rmse:3336.52+33.4641	test-rmse:3339.23+23.2949
# [17]	train-rmse:3261.94+23.1701	test-rmse:3264.95+14.3471
# [18]	train-rmse:3199.75+27.434	test-rmse:3202.97+16.3179
# [19]	train-rmse:3153.82+30.2838	test-rmse:3157.36+15.7673
# [20]	train-rmse:3105.69+25.0389	test-rmse:3109.66+11.0988
# [21]	train-rmse:3067.23+19.4224	test-rmse:3071.47+10.4909
# [22]	train-rmse:3039.6+20.9891	test-rmse:3043.91+15.6083
# [23]	train-rmse:3013.55+17.4781	test-rmse:3018.11+15.6218
# [24]	train-rmse:2992.11+16.499	test-rmse:2997.04+12.8351
# [25]	train-rmse:2969.65+14.0786	test-rmse:2975+12.6487
# [26]	train-rmse:2951.53+10.1375	test-rmse:2957.06+13.2754
# [27]	train-rmse:2935.52+8.50838	test-rmse:2941.32+14.1244
# [28]	train-rmse:2924.17+10.2972	test-rmse:2930.18+12.8311
# [29]	train-rmse:2913.47+7.9192	test-rmse:2919.7+13.226
# [30]	train-rmse:2902.92+7.27142	test-rmse:2909.39+14.5744
# [31]	train-rmse:2894.96+6.09264	test-rmse:2901.8+15.3249
# [32]	train-rmse:2886.94+6.6766	test-rmse:2893.97+16.2052
# [33]	train-rmse:2880.25+5.78074	test-rmse:2887.34+16.6868
# [34]	train-rmse:2874.55+6.50195	test-rmse:2881.68+16.6241
# [35]	train-rmse:2869.25+4.59461	test-rmse:2876.59+17.9027
# [36]	train-rmse:2864.26+4.65165	test-rmse:2871.71+18.4056
# [37]	train-rmse:2860+4.96639	test-rmse:2867.63+16.9464
# [38]	train-rmse:2856.01+5.29915	test-rmse:2863.87+16.4781
# [39]	train-rmse:2850.69+5.29267	test-rmse:2858.68+17.0528
# [40]	train-rmse:2846.77+5.58696	test-rmse:2854.9+16.6945
# [41]	train-rmse:2843.53+5.48028	test-rmse:2851.89+16.3844
# [42]	train-rmse:2839.82+5.09449	test-rmse:2848.52+16.196
# [43]	train-rmse:2836.32+4.75463	test-rmse:2845.17+16.5175
# [44]	train-rmse:2833.14+4.77138	test-rmse:2842.19+16.5818
# [45]	train-rmse:2829.65+4.83346	test-rmse:2838.79+16.1756
# [46]	train-rmse:2826.57+4.82783	test-rmse:2835.86+16.2682
# [47]	train-rmse:2823.22+4.86262	test-rmse:2832.7+16.5736
# [48]	train-rmse:2820.56+5.09562	test-rmse:2830.3+16.8802
# [49]	train-rmse:2818.88+5.10025	test-rmse:2828.85+17.0759
# test-rmse-mean     3649.034757
# test-rmse-std        29.120767
# train-rmse-mean    3644.145512
# train-rmse-std       26.780673
# dtype: float64 test-rmse-mean     1340.851878
# test-rmse-std        25.253662
# train-rmse-mean    1343.282490
# train-rmse-std       28.974709
# dtype: float64

# %%
#second model
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(input.astype(int))
tfidf
# Out:
# <550068x11 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5137016 stored elements in Compressed Sparse Row format>

# %%
input_tfidf=tfidf.toarray()

# %%
params = {}
params["min_child_weight"] = 10
params["subsample"] = 0.7
params["colsample_bytree"] = 0.7
params["scale_pos_weight"] = 0.8
params["silent"] = 1
params["max_depth"] = 12
params["nthread"] = 6
#params["gamma"] = 1
params["objective"] = "reg:linear"
params["eta"] = 0.1
params["base_score"] = 1800
params["eval_metric"] = "rmse"
params["seed"] = 0

plst = list(params.items())
num_rounds = 1800

# %%
xgtrain = xgb.DMatrix(input_tfidf[:train.shape[0],:], label=target[:train.shape[0]])
watchlist = [(xgtrain, 'train')]
model_1_xgboost = xgb.train(plst, xgtrain, num_rounds)

# %%
model_1_predict = model_1_xgboost.predict(xgb.DMatrix(input_tfidf[train.shape[0]:,:]))
model_1_predict[model_1_predict<0] = 25
submission.Purchase = model_1_predict
submission.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday3070\second_model.csv',index=False)
pickle.dump(model_1_xgboost, open("model_2.pickle.dat", "wb"))

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8270.79+2.52549	test-rmse:8273.33+11.1995
# [1]	train-rmse:7647.46+34.6748	test-rmse:7654.59+26.2599
# [2]	train-rmse:7099.66+40.9174	test-rmse:7112.07+34.6939
# [3]	train-rmse:6605.91+57.6842	test-rmse:6622.92+54.9059
# [4]	train-rmse:6163.61+69.7494	test-rmse:6185.59+69.9872
# [5]	train-rmse:5775.28+58.3191	test-rmse:5803.01+62.1079
# [6]	train-rmse:5420.99+42.5635	test-rmse:5454.7+43.9829
# [7]	train-rmse:5114.08+46.4099	test-rmse:5153.81+50.2424
# [8]	train-rmse:4853.89+29.6288	test-rmse:4900.95+31.5877
# [9]	train-rmse:4614.8+25.6266	test-rmse:4667.77+27.435
# [10]	train-rmse:4423.42+23.7751	test-rmse:4483.54+18.9942
# [11]	train-rmse:4254.05+28.6478	test-rmse:4320.61+27.9948
# [12]	train-rmse:4108+34.9392	test-rmse:4181.85+30.4452
# [13]	train-rmse:3986.06+36.0641	test-rmse:4067.44+36.4114
# [14]	train-rmse:3871.3+29.1757	test-rmse:3959.46+30.3682
# [15]	train-rmse:3783.06+27.9324	test-rmse:3878.62+26.9547
# [16]	train-rmse:3701.7+28.9798	test-rmse:3803.34+23.6973
# [17]	train-rmse:3630.1+27.1929	test-rmse:3738.44+22.6674
# [18]	train-rmse:3571.72+29.7018	test-rmse:3686.22+24.9987
# [19]	train-rmse:3523.76+32.3174	test-rmse:3645.65+26.0199
# [20]	train-rmse:3474.02+28.2391	test-rmse:3601.4+21.6355
# [21]	train-rmse:3432.88+21.9324	test-rmse:3565.59+17.2546
# [22]	train-rmse:3400.7+23.1974	test-rmse:3539.29+19.6534
# [23]	train-rmse:3370.25+18.3224	test-rmse:3514.61+15.1929
# [24]	train-rmse:3343.37+22.4879	test-rmse:3493.08+16.9521
# [25]	train-rmse:3314.22+18.7186	test-rmse:3468.7+14.1636
# [26]	train-rmse:3289.74+14.9653	test-rmse:3449.44+12.2888
# [27]	train-rmse:3270.32+14.9273	test-rmse:3434.76+10.0986
# [28]	train-rmse:3253.25+16.6366	test-rmse:3422.83+12.1341
# [29]	train-rmse:3237.01+14.9905	test-rmse:3411.3+11.1351
# [30]	train-rmse:3220.16+15.4101	test-rmse:3398.15+9.74908
# [31]	train-rmse:3200.97+16.1216	test-rmse:3384.08+12.8797
# [32]	train-rmse:3185.85+14.8672	test-rmse:3373.29+9.73155
# [33]	train-rmse:3170.71+15.1356	test-rmse:3362.56+7.97545
# [34]	train-rmse:3159.5+21.9351	test-rmse:3355.05+11.7737
# [35]	train-rmse:3150.64+20.8674	test-rmse:3349.96+11.7467
# [36]	train-rmse:3137.67+19.9735	test-rmse:3340.89+8.15716
# [37]	train-rmse:3127.19+21.9656	test-rmse:3334.18+6.84338
# [38]	train-rmse:3118.13+23.3365	test-rmse:3328.66+7.41358
# [39]	train-rmse:3111.28+22.059	test-rmse:3324.81+7.03616
# [40]	train-rmse:3100.34+18.1456	test-rmse:3317.76+4.50243
# [41]	train-rmse:3093.03+19.5469	test-rmse:3314.43+4.66079
# [42]	train-rmse:3086.73+19.0659	test-rmse:3311.17+5.56469
# [43]	train-rmse:3072.69+22.6478	test-rmse:3301.86+9.00018
# [44]	train-rmse:3061.91+21.5755	test-rmse:3294.67+7.39887
# [45]	train-rmse:3051.23+20.1415	test-rmse:3288.4+8.07861
# [46]	train-rmse:3044.03+25.2488	test-rmse:3283.79+8.89355
# [47]	train-rmse:3039.3+21.9518	test-rmse:3281.25+6.85411
# [48]	train-rmse:3033.9+20.7286	test-rmse:3278.46+6.03982
# [49]	train-rmse:3030.85+19.8186	test-rmse:3277.55+5.85967
# test-rmse-mean     4059.917233
# test-rmse-std        19.832442
# train-rmse-mean    3920.030145
# train-rmse-std       26.035713
# dtype: float64 test-rmse-mean     1222.500721
# test-rmse-std        15.342932
# train-rmse-mean    1286.696943
# train-rmse-std       12.174374
# dtype: float64

# %%
#third model
input_w_tfidf=np.concatenate((input,input_tfidf),axis=1)

# %%
params = {}
params["min_child_weight"] = 10
params["subsample"] = 0.7
params["colsample_bytree"] = 0.7
params["scale_pos_weight"] = 0.8
params["silent"] = 1
params["max_depth"] = 8
params["nthread"] = 6
#params["gamma"] = 1
params["objective"] = "reg:linear"
params["eta"] = 0.1
params["base_score"] = 1800
params["eval_metric"] = "rmse"
params["seed"] = 0

plst = list(params.items())
num_rounds = 1750

xgtrain=xgb.DMatrix(input_w_tfidf[:train.shape[0],:],label=target[:train.shape[0]])
watchlist=[(xgtrain,'train')]
model_1_xgboost = xgb.train(plst, xgtrain, num_rounds)

model_1_predict = model_1_xgboost.predict(xgb.DMatrix(input_w_tfidf[train.shape[0]:,:]))
model_1_predict[model_1_predict<0] = 25
submission.Purchase = model_1_predict
submission.to_csv(r"C:\Users\sk\AnacondaProjects\blackfriday3070\third_model.csv", index=False)
pickle.dump(model_1_xgboost, open("model_3.pickle.dat", "wb"))

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8217.78+2.65559	test-rmse:8218.04+11.0596
# [1]	train-rmse:7502.67+2.30984	test-rmse:7503.59+11.1718
# [2]	train-rmse:6882.17+25.5452	test-rmse:6883.56+30.078
# [3]	train-rmse:6328.83+23.2282	test-rmse:6330.52+33.6598
# [4]	train-rmse:5831.18+20.8992	test-rmse:5833.29+31.9983
# [5]	train-rmse:5402.86+18.1226	test-rmse:5405.83+28.3776
# [6]	train-rmse:5031.91+18.5392	test-rmse:5035.85+21.24
# [7]	train-rmse:4709.43+20.2667	test-rmse:4714.22+20.6391
# [8]	train-rmse:4415.01+18.3932	test-rmse:4420.63+17.9856
# [9]	train-rmse:4166.11+22.122	test-rmse:4172.68+15.8729
# [10]	train-rmse:3947.47+19.3695	test-rmse:3955.05+12.9174
# [11]	train-rmse:3772.66+25.7603	test-rmse:3781.14+15.9347
# [12]	train-rmse:3615.62+26.6529	test-rmse:3625.48+18.0974
# [13]	train-rmse:3482.8+22.813	test-rmse:3493.82+17.6617
# [14]	train-rmse:3368.83+23.8003	test-rmse:3381.02+14.3653
# [15]	train-rmse:3278.54+20.9279	test-rmse:3291.97+14.5364
# [16]	train-rmse:3199.15+22.8082	test-rmse:3213.91+19.1974
# [17]	train-rmse:3134.37+20.772	test-rmse:3150.57+16.68
# [18]	train-rmse:3074.87+19.9835	test-rmse:3092.21+12.7921
# [19]	train-rmse:3026.08+14.9301	test-rmse:3044.73+10.6366
# [20]	train-rmse:2986.51+13.1267	test-rmse:3006.2+8.84946
# [21]	train-rmse:2951.72+13.7901	test-rmse:2972.6+8.93251
# [22]	train-rmse:2920.06+11.9329	test-rmse:2942.13+8.67183
# [23]	train-rmse:2894.06+11.1045	test-rmse:2917.53+9.23019
# [24]	train-rmse:2871.66+8.97288	test-rmse:2896.11+11.3387
# [25]	train-rmse:2852.88+9.1519	test-rmse:2878.57+11.4285
# [26]	train-rmse:2836.32+8.91499	test-rmse:2863.07+12.1662
# [27]	train-rmse:2822.44+8.38806	test-rmse:2850.35+12.7609
# [28]	train-rmse:2809.56+7.52262	test-rmse:2838.69+13.0864
# [29]	train-rmse:2799.15+7.21768	test-rmse:2829.47+13.7352
# [30]	train-rmse:2789.03+7.92181	test-rmse:2820.59+13.5771
# [31]	train-rmse:2780.85+7.68253	test-rmse:2813.58+14.0617
# [32]	train-rmse:2773.35+7.66502	test-rmse:2807.1+14.7352
# [33]	train-rmse:2767.25+7.65189	test-rmse:2802.07+14.821
# [34]	train-rmse:2761.18+6.85925	test-rmse:2797.1+15.993
# [35]	train-rmse:2754.81+6.45939	test-rmse:2791.71+16.3567
# [36]	train-rmse:2748.92+6.0023	test-rmse:2786.75+15.9623
# [37]	train-rmse:2744.02+5.11849	test-rmse:2782.94+16.7267
# [38]	train-rmse:2739.12+5.43291	test-rmse:2779.23+16.9214
# [39]	train-rmse:2734.45+4.77481	test-rmse:2775.71+17.4941
# [40]	train-rmse:2730.35+4.75877	test-rmse:2772.83+17.5824
# [41]	train-rmse:2726.33+5.58762	test-rmse:2770.05+17.4548
# [42]	train-rmse:2722.78+5.34498	test-rmse:2767.37+17.647
# [43]	train-rmse:2718.52+5.57851	test-rmse:2764.2+17.7166
# [44]	train-rmse:2715.06+5.44439	test-rmse:2761.77+17.9599
# [45]	train-rmse:2711.2+5.54164	test-rmse:2758.92+18.0611
# [46]	train-rmse:2707.97+5.25966	test-rmse:2756.55+18.7342
# [47]	train-rmse:2704.46+5.02689	test-rmse:2753.92+18.3342
# [48]	train-rmse:2700.96+5.08604	test-rmse:2751.4+18.2317
# [49]	train-rmse:2697.54+6.1662	test-rmse:2748.76+17.3826
# test-rmse-mean     3542.107880
# test-rmse-std        16.417108
# train-rmse-mean    3517.216895
# train-rmse-std       12.187701
# dtype: float64 test-rmse-mean     1331.529950
# test-rmse-std         5.381332
# train-rmse-mean    1343.615588
# train-rmse-std        7.500863
# dtype: float64

# %%
print (train.shape, train[train.Marital_Status==0].shape)
# Out:
# (385049, 12) (227272, 12)

# %%
#fourth model
model_4_et = ExtraTreesRegressor(n_estimators=1450, max_depth=8,min_samples_split=10, min_samples_leaf=10, oob_score=True, n_jobs=6, random_state=123, verbose=1, bootstrap=True)
model_4_et.fit(input_w_tfidf[:train.shape[0],:], target[:train.shape[0]])
model_4_predict = model_4_et.predict(input_w_tfidf[train.shape[0]:,:])
submission.Purchase = model_4_predict
submission.to_csv(r"C:\Users\sk\AnacondaProjects\blackfriday3070\fourth_model.csv", index=False)
pickle.dump(model_4_et, open("model_4.pickle.dat", "wb"))
# Out:
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=6)]: Done 1450 out of 1450 | elapsed: 11.4min finished
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=6)]: Done 1450 out of 1450 | elapsed:    3.3s finished

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
temp=pd.read_csv('submission.csv')
temp_sample=temp['Purchase']
temp=pd.read_csv('first_model.csv')
temp_first=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_first)))
temp=pd.read_csv('second_model.csv')
temp_second=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_second)))
temp=pd.read_csv('third_model.csv')
temp_third=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_third)))
temp=pd.read_csv('fourth_model.csv')
temp_fourth=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_fourth)))
# Out:
# 3098.68227164
# 3232.73452893
# 3030.01405997
# 3252.04289886

# %%
import matplotlib.pyplot as plt
temp=pd.read_csv('submission.csv')
temp_first=pd.read_csv('first_model.csv')
x1=temp_first['User_ID'].astype(int)
plt.plot(x1[:100],temp_first['Purchase'][:100],color='red')
x=temp['User_ID'].astype(int)
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_second=pd.read_csv('second_model.csv')
x2=temp_second['User_ID'].astype(int)
plt.plot(x2[:100],temp_second['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_third=pd.read_csv('third_model.csv')
x3=temp_third['User_ID'].astype(int)
plt.plot(x3[:100],temp_third['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_fourth=pd.read_csv('fourth_model.csv')
x4=temp_fourth['User_ID'].astype(int)
plt.plot(x4[:100],temp_fourth['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()


#plotting all together

plt.plot(x1[:100],temp_first['Purchase'][:100],color='red',label='Model1')
plt.plot(x2[:100],temp_second['Purchase'][:100],color='green',label='Model2')
plt.plot(x3[:100],temp_third['Purchase'][:100],color='cyan',label='Model3')
plt.plot(x4[:100],temp_fourth['Purchase'][:100],color='black',label='Model4')
plt.plot(x[:100],temp['Purchase'][:100],color='blue',label='Original')
plt.legend(loc='best')
plt.xlabel('Users')
plt.ylabel('Purchase')
plt.show()
