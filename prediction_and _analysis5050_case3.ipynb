# %%
import numpy as np
import pandas as pd

# %%
input=pd.read_csv('input.csv')
input.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
train=input[:275035]
test=input[275035:]
train.info()
test.info()
train.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday5050\train.csv',index=False)
test.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday5050\test.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275035 entries, 0 to 275034
# Data columns (total 12 columns):
# User_ID                       275035 non-null int64
# Product_ID                    275035 non-null object
# Gender                        275035 non-null object
# Age                           275035 non-null object
# Occupation                    275035 non-null int64
# City_Category                 275035 non-null object
# Stay_In_Current_City_Years    275035 non-null object
# Marital_Status                275035 non-null int64
# Product_Category_1            275035 non-null int64
# Product_Category_2            189846 non-null float64
# Product_Category_3            84325 non-null float64
# Purchase                      275035 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 25.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275033 entries, 275035 to 550067
# Data columns (total 12 columns):
# User_ID                       275033 non-null int64
# Product_ID                    275033 non-null object
# Gender                        275033 non-null object
# Age                           275033 non-null object
# Occupation                    275033 non-null int64
# City_Category                 275033 non-null object
# Stay_In_Current_City_Years    275033 non-null object
# Marital_Status                275033 non-null int64
# Product_Category_1            275033 non-null int64
# Product_Category_2            186584 non-null float64
# Product_Category_3            82496 non-null float64
# Purchase                      275033 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 25.2+ MB

# %%
submission=input.loc[275035:,['User_ID','Product_ID','Purchase']]

# %%
submission.head()
submission.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday5050\submission.csv',index=False)

# %%
test.head()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 275035  1000388  P00202142      F  26-35           0             B
# 275036  1000388  P00087142      F  26-35           0             B
# 275037  1000388  P00271042      F  26-35           0             B
# 275038  1000388  P00327342      F  26-35           0             B
# 275039  1000390  P00348642      M  26-35           4             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 275035                          3               1                   8
# 275036                          3               1                  13
# 275037                          3               1                   6
# 275038                          3               1                  16
# 275039                          0               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 275035                16.0                17.0      8126
# 275036                14.0                16.0       928
# 275037                16.0                 NaN     12600
# 275038                 NaN                 NaN     16207
# 275039                11.0                 NaN      6958

# %%
del(test['Purchase'])

# %%
test.head()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 275035  1000388  P00202142      F  26-35           0             B
# 275036  1000388  P00087142      F  26-35           0             B
# 275037  1000388  P00271042      F  26-35           0             B
# 275038  1000388  P00327342      F  26-35           0             B
# 275039  1000390  P00348642      M  26-35           4             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 275035                          3               1                   8
# 275036                          3               1                  13
# 275037                          3               1                   6
# 275038                          3               1                  16
# 275039                          0               0                   5
#
#         Product_Category_2  Product_Category_3
# 275035                16.0                17.0
# 275036                14.0                16.0
# 275037                16.0                 NaN
# 275038                 NaN                 NaN
# 275039                11.0                 NaN

# %%
test.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday5050\test.csv',index=False)

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
import seaborn as sns
sns.pairplot(train.dropna(),hue='Gender')

# %%
sns.pairplot(train.dropna(),hue='Age')

# %%
sns.pairplot(train.dropna())

# %%
frames=[train,test]
input=pd.concat(frames)
input.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday5050\input_total.csv',index=False)
print (input.shape)
input.head()
# Out:
# (550068, 12)
#     Age City_Category Gender  Marital_Status  Occupation  Product_Category_1  \
# 0  0-17             A      F               0          10                   3
# 1  0-17             A      F               0          10                   1
# 2  0-17             A      F               0          10                  12
# 3  0-17             A      F               0          10                  12
# 4   55+             C      M               0          16                   8
#
#    Product_Category_2  Product_Category_3 Product_ID  Purchase  \
# 0                 NaN                 NaN  P00069042    8370.0
# 1                 6.0                14.0  P00248942   15200.0
# 2                 NaN                 NaN  P00087842    1422.0
# 3                14.0                 NaN  P00085442    1057.0
# 4                 NaN                 NaN  P00285442    7969.0
#
#   Stay_In_Current_City_Years  User_ID
# 0                          2  1000001
# 1                          2  1000001
# 2                          2  1000001
# 3                          2  1000001
# 4                         4+  1000002

# %%
input.dtypes
# Out:
# Age                            object
# City_Category                  object
# Gender                         object
# Marital_Status                  int64
# Occupation                      int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Product_ID                     object
# Purchase                      float64
# Stay_In_Current_City_Years     object
# User_ID                         int64
# dtype: object

# %%
input.fillna(999,inplace=True)
input.head()
# Out:
#     Age City_Category Gender  Marital_Status  Occupation  Product_Category_1  \
# 0  0-17             A      F               0          10                   3
# 1  0-17             A      F               0          10                   1
# 2  0-17             A      F               0          10                  12
# 3  0-17             A      F               0          10                  12
# 4   55+             C      M               0          16                   8
#
#    Product_Category_2  Product_Category_3 Product_ID  Purchase  \
# 0               999.0               999.0  P00069042    8370.0
# 1                 6.0                14.0  P00248942   15200.0
# 2               999.0               999.0  P00087842    1422.0
# 3                14.0               999.0  P00085442    1057.0
# 4               999.0               999.0  P00285442    7969.0
#
#   Stay_In_Current_City_Years  User_ID
# 0                          2  1000001
# 1                          2  1000001
# 2                          2  1000001
# 3                          2  1000001
# 4                         4+  1000002

# %%
target=input.Purchase
target=np.array(target)
input.drop(['Purchase'],axis=1,inplace=True)

# %%
print(input.columns,input.dtypes)
# Out:
# Index(['Age', 'City_Category', 'Gender', 'Marital_Status', 'Occupation',
#        'Product_Category_1', 'Product_Category_2', 'Product_Category_3',
#        'Product_ID', 'Stay_In_Current_City_Years', 'User_ID'],
#       dtype='object') Age                            object
# City_Category                  object
# Gender                         object
# Marital_Status                  int64
# Occupation                      int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Product_ID                     object
# Stay_In_Current_City_Years     object
# User_ID                         int64
# dtype: object

# %%
input=input.applymap(str)
input.dtypes
# Out:
# Age                           object
# City_Category                 object
# Gender                        object
# Marital_Status                object
# Occupation                    object
# Product_Category_1            object
# Product_Category_2            object
# Product_Category_3            object
# Product_ID                    object
# Stay_In_Current_City_Years    object
# User_ID                       object
# dtype: object

# %%
input_pd=input.copy()

# %%
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer


from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn import linear_model

from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
input=np.array(input)

for i in range(input.shape[1]):
    lbl=preprocessing.LabelEncoder()
    lbl.fit(list(input[:,i]))
    input[:,i]=lbl.transform(input[:,i])

# %%
print(input[4])
input=input.astype(int)
# Out:
# [6 2 1 0 8 18 17 15 2734 4 1]

# %%
#xgboost model
import xgboost as xgb
params={}
params['min_child_weight']=10
params['subsample']=0.7
params['colsample_bytree']=0.7
params['scale_pos_weight']=0.8
params['silent']=1                                                                                                                                        
params['max_depth']=6
params['nthread']=6
params['objective']='reg:linear'
params['eta']=0.1
params['base_score']=1800
params['eval_metric']='rmse'
params['seed']=0
plst=list(params.items())
num_rounds=300

# %%
import matplotlib.pyplot as plt
from xgboost import XGBClassifier, plot_importance
xgtrain=xgb.DMatrix(input[:train.shape[0],:],label=target[:train.shape[0]])
watchlist=[(xgtrain,'train')]
model_1_xgboost=xgb.train(plst,xgtrain,num_rounds)
plot_importance(model_1_xgboost)
plt.show()
'''print(model_1_xgboost.feature_importances_)
plt.bar(range(len(model_1_xgboost.feature_importances_)),model_1_xgboost.feature_importances_)
plt.show()'''
model_1_xgboost.get_score(importance_type='gain')
# Out:
# {'f0': 70060371.20117746,
#  'f1': 150959442.24687955,
#  'f10': 113336469.909695,
#  'f2': 62917851.95544554,
#  'f3': 54799929.557692304,
#  'f4': 69418926.51908302,
#  'f5': 8162556395.881068,
#  'f6': 770935033.9008082,
#  'f7': 897951689.1148698,
#  'f8': 547157523.5263566,
#  'f9': 66450518.57493976}

# %%
import pickle
pickle.dump(model_1_xgboost, open("model_1_xgboost.pickle.dat", "wb"))

# %%
model_1_predict=model_1_xgboost.predict(xgb.DMatrix(input[train.shape[0]:,:]))
model_1_predict[model_1_predict<0]=25
submission.Purchase=model_1_predict
#submission.to_csv('../submission/submit_13.csv',index=False)
submission.to_csv(r'C:/Users/sk/AnacondaProjects/blackfriday5050/first_model.csv',index=False)

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8339.6+2.64154	test-rmse:8339.63+11.7719
# [1]	train-rmse:7670.16+68.0311	test-rmse:7670.66+64.2341
# [2]	train-rmse:7070.38+98.4166	test-rmse:7071.46+98.9826
# [3]	train-rmse:6516.2+102.722	test-rmse:6517.79+99.1793
# [4]	train-rmse:6040.46+59.273	test-rmse:6041.61+54.3406
# [5]	train-rmse:5628.53+82.4949	test-rmse:5630.37+78.6192
# [6]	train-rmse:5281.15+78.3846	test-rmse:5283.57+78.8125
# [7]	train-rmse:4960.34+80.2856	test-rmse:4963.01+85.511
# [8]	train-rmse:4675.81+64.3349	test-rmse:4678.53+67.585
# [9]	train-rmse:4429.1+79.7917	test-rmse:4431.96+80.2045
# [10]	train-rmse:4210.67+60.463	test-rmse:4213.45+56.2854
# [11]	train-rmse:4011.48+58.3036	test-rmse:4014.22+51.0819
# [12]	train-rmse:3857.72+34.0258	test-rmse:3860.91+27.7174
# [13]	train-rmse:3730.59+46.1272	test-rmse:3733.79+41.4943
# [14]	train-rmse:3599.98+47.0944	test-rmse:3603.56+45.9641
# [15]	train-rmse:3503.19+49.0198	test-rmse:3506.83+45.287
# [16]	train-rmse:3397.15+41.7311	test-rmse:3401.1+38.7432
# [17]	train-rmse:3317.53+43.6828	test-rmse:3321.9+41.8702
# [18]	train-rmse:3249.97+31.9662	test-rmse:3255.2+29.6009
# [19]	train-rmse:3200.07+27.2278	test-rmse:3205.63+21.6141
# [20]	train-rmse:3153.49+22.3051	test-rmse:3159.51+14.9502
# [21]	train-rmse:3111.72+19.25	test-rmse:3118.23+12.8438
# [22]	train-rmse:3086.17+22.8437	test-rmse:3093+15.1158
# [23]	train-rmse:3048.74+19.0172	test-rmse:3056.02+11.8652
# [24]	train-rmse:3019.58+17.6419	test-rmse:3026.99+13.1048
# [25]	train-rmse:2995.75+17.8257	test-rmse:3003.41+15.8422
# [26]	train-rmse:2975.2+19.1369	test-rmse:2982.92+18.9539
# [27]	train-rmse:2958.12+15.5597	test-rmse:2966.32+14.7924
# [28]	train-rmse:2945.21+15.3461	test-rmse:2953.65+16.0925
# [29]	train-rmse:2933.83+13.6694	test-rmse:2942.62+12.8651
# [30]	train-rmse:2922.7+10.8909	test-rmse:2931.79+10.3826
# [31]	train-rmse:2914.81+10.8099	test-rmse:2924.34+12.5639
# [32]	train-rmse:2907.68+9.95547	test-rmse:2917.53+13.7238
# [33]	train-rmse:2898.91+10.5247	test-rmse:2908.9+14.9321
# [34]	train-rmse:2890.82+11.5799	test-rmse:2901.03+16.6155
# [35]	train-rmse:2882.33+9.74489	test-rmse:2892.8+14.6733
# [36]	train-rmse:2876.72+10.3245	test-rmse:2887.41+15.9681
# [37]	train-rmse:2871.4+8.98746	test-rmse:2882.25+14.1268
# [38]	train-rmse:2865.29+8.40063	test-rmse:2876.56+11.7217
# [39]	train-rmse:2859.94+6.99379	test-rmse:2871.46+10.4768
# [40]	train-rmse:2854.1+5.79653	test-rmse:2866.03+10.2271
# [41]	train-rmse:2849.59+5.68426	test-rmse:2861.88+10.0155
# [42]	train-rmse:2845.55+5.37946	test-rmse:2858.14+10.4876
# [43]	train-rmse:2841.63+5.35933	test-rmse:2854.44+10.636
# [44]	train-rmse:2838.72+5.71147	test-rmse:2851.8+10.7226
# [45]	train-rmse:2835.11+4.99717	test-rmse:2848.58+9.64249
# [46]	train-rmse:2831.8+5.13597	test-rmse:2845.36+9.43997
# [47]	train-rmse:2828.1+5.06111	test-rmse:2841.87+9.0894
# [48]	train-rmse:2825.26+4.70543	test-rmse:2839.21+9.16797
# [49]	train-rmse:2822.57+4.37198	test-rmse:2836.79+9.18586
# test-rmse-mean     3690.920226
# test-rmse-std        29.982482
# train-rmse-mean    3683.619124
# train-rmse-std       29.780561
# dtype: float64 test-rmse-mean     1360.359768
# test-rmse-std        26.598630
# train-rmse-mean    1363.662124
# train-rmse-std       28.206307
# dtype: float64

# %%
#second model
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(input.astype(int))
tfidf
# Out:
# <550068x11 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5137016 stored elements in Compressed Sparse Row format>

# %%
input_tfidf=tfidf.toarray()

# %%
params = {}
params["min_child_weight"] = 10
params["subsample"] = 0.7
params["colsample_bytree"] = 0.7
params["scale_pos_weight"] = 0.8
params["silent"] = 1
params["max_depth"] = 12
params["nthread"] = 6
#params["gamma"] = 1
params["objective"] = "reg:linear"
params["eta"] = 0.1
params["base_score"] = 1800
params["eval_metric"] = "rmse"
params["seed"] = 0

plst = list(params.items())
num_rounds = 1800

# %%
xgtrain = xgb.DMatrix(input_tfidf[:train.shape[0],:], label=target[:train.shape[0]])
watchlist = [(xgtrain, 'train')]
model_1_xgboost = xgb.train(plst, xgtrain, num_rounds)

# %%
model_1_predict = model_1_xgboost.predict(xgb.DMatrix(input_tfidf[train.shape[0]:,:]))
model_1_predict[model_1_predict<0] = 25
submission.Purchase = model_1_predict
submission.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday5050\second_model.csv',index=False)
pickle.dump(model_1_xgboost, open("model_2.pickle.dat", "wb"))

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8333.8+2.99275	test-rmse:8339.97+11.4121
# [1]	train-rmse:7703.03+50.2488	test-rmse:7715.71+49.6803
# [2]	train-rmse:7133.83+67.2143	test-rmse:7153.7+70.9271
# [3]	train-rmse:6626.1+76.3394	test-rmse:6652.19+76.3878
# [4]	train-rmse:6182.74+46.2057	test-rmse:6214.13+45.6077
# [5]	train-rmse:5801.06+61.6854	test-rmse:5840.61+60.8508
# [6]	train-rmse:5472.76+57.5852	test-rmse:5521.32+61.0826
# [7]	train-rmse:5171.28+53.8041	test-rmse:5227.98+60.059
# [8]	train-rmse:4904.93+46.6904	test-rmse:4969.95+52.9827
# [9]	train-rmse:4675.44+54.3777	test-rmse:4749.07+61.7044
# [10]	train-rmse:4475.65+40.7865	test-rmse:4557.94+45.7683
# [11]	train-rmse:4294.72+40.4859	test-rmse:4384.88+44.8881
# [12]	train-rmse:4153.41+22.6937	test-rmse:4252.82+27.016
# [13]	train-rmse:4030.72+31.3354	test-rmse:4140.37+37.5667
# [14]	train-rmse:3912.08+32.1461	test-rmse:4030.12+39.3153
# [15]	train-rmse:3819.61+32.8158	test-rmse:3946.75+41.0494
# [16]	train-rmse:3722.39+27.1034	test-rmse:3857.59+36.5447
# [17]	train-rmse:3644.3+27.2408	test-rmse:3787.86+36.2303
# [18]	train-rmse:3579.36+21.4164	test-rmse:3730.87+28.4511
# [19]	train-rmse:3526.04+20.9378	test-rmse:3685.64+26.5326
# [20]	train-rmse:3475.47+17.5133	test-rmse:3642.5+21.4158
# [21]	train-rmse:3434+17.2526	test-rmse:3608.65+21.4805
# [22]	train-rmse:3403.41+20.6598	test-rmse:3586.53+23.825
# [23]	train-rmse:3360.97+16.308	test-rmse:3550.07+19.7048
# [24]	train-rmse:3326.93+10.7852	test-rmse:3521.68+15.3962
# [25]	train-rmse:3296.1+16.4867	test-rmse:3496.28+19.4241
# [26]	train-rmse:3271.94+17.9177	test-rmse:3478.58+21.7503
# [27]	train-rmse:3251.95+16.7608	test-rmse:3464.59+18.5249
# [28]	train-rmse:3232.79+16.8383	test-rmse:3450.52+21.8043
# [29]	train-rmse:3217.16+15.7572	test-rmse:3440.96+20.1598
# [30]	train-rmse:3197.01+17.9864	test-rmse:3426.6+19.7345
# [31]	train-rmse:3186.57+19.5378	test-rmse:3420.72+20.3835
# [32]	train-rmse:3174.58+19.3111	test-rmse:3413.5+22.3537
# [33]	train-rmse:3159.19+18.3941	test-rmse:3402.58+21.7953
# [34]	train-rmse:3147.68+20.3212	test-rmse:3395.23+24.1472
# [35]	train-rmse:3133.7+14.6061	test-rmse:3385.74+19.2797
# [36]	train-rmse:3124.14+16.0351	test-rmse:3380.41+21.3032
# [37]	train-rmse:3114.02+11.9548	test-rmse:3374.1+17.663
# [38]	train-rmse:3100.41+10.8171	test-rmse:3365.68+15.1263
# [39]	train-rmse:3086.07+8.40381	test-rmse:3356.08+14.8001
# [40]	train-rmse:3075.6+6.92675	test-rmse:3350.83+13.9539
# [41]	train-rmse:3061.61+5.48642	test-rmse:3341.39+15.8054
# [42]	train-rmse:3051.72+9.12134	test-rmse:3335.25+18.3982
# [43]	train-rmse:3044.62+10.3814	test-rmse:3332.1+19.6883
# [44]	train-rmse:3040.16+11.2355	test-rmse:3330.68+20.2272
# [45]	train-rmse:3024.96+12.5706	test-rmse:3320.72+21.8577
# [46]	train-rmse:3019.9+12.034	test-rmse:3318.62+21.927
# [47]	train-rmse:3011.82+10.2389	test-rmse:3314.06+18.5977
# [48]	train-rmse:3004.27+11.7676	test-rmse:3310.28+19.0177
# [49]	train-rmse:2995+12.9327	test-rmse:3305.48+20.4944
# test-rmse-mean     4103.597117
# test-rmse-std        30.081931
# train-rmse-mean    3923.740383
# train-rmse-std       24.808960
# dtype: float64 test-rmse-mean     1229.228887
# test-rmse-std        16.536398
# train-rmse-mean    1309.723386
# train-rmse-std       17.632766
# dtype: float64

# %%
#third model
input_w_tfidf=np.concatenate((input,input_tfidf),axis=1)

# %%
params = {}
params["min_child_weight"] = 10
params["subsample"] = 0.7
params["colsample_bytree"] = 0.7
params["scale_pos_weight"] = 0.8
params["silent"] = 1
params["max_depth"] = 8
params["nthread"] = 6
#params["gamma"] = 1
params["objective"] = "reg:linear"
params["eta"] = 0.1
params["base_score"] = 1800
params["eval_metric"] = "rmse"
params["seed"] = 0

plst = list(params.items())
num_rounds = 1750

xgtrain=xgb.DMatrix(input_w_tfidf[:train.shape[0],:],label=target[:train.shape[0]])
watchlist=[(xgtrain,'train')]
model_1_xgboost = xgb.train(plst, xgtrain, num_rounds)

model_1_predict = model_1_xgboost.predict(xgb.DMatrix(input_w_tfidf[train.shape[0]:,:]))
model_1_predict[model_1_predict<0] = 25
submission.Purchase = model_1_predict
submission.to_csv(r"C:\Users\sk\AnacondaProjects\blackfriday5050\third_model.csv", index=False)
pickle.dump(model_1_xgboost, open("model_3.pickle.dat", "wb"))

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8212.35+2.55303	test-rmse:8212.67+11.5159
# [1]	train-rmse:7525.68+31.2425	test-rmse:7526.99+34.6622
# [2]	train-rmse:6890.51+28.9983	test-rmse:6892.49+32.5777
# [3]	train-rmse:6349.48+45.9703	test-rmse:6352.19+51.2674
# [4]	train-rmse:5857.79+35.9843	test-rmse:5861.27+38.4721
# [5]	train-rmse:5439.62+26.1768	test-rmse:5444.07+26.5682
# [6]	train-rmse:5064.73+8.87403	test-rmse:5070.17+15.6223
# [7]	train-rmse:4725.66+8.16884	test-rmse:4732.26+15.0661
# [8]	train-rmse:4446.64+27.391	test-rmse:4454.72+35.3686
# [9]	train-rmse:4201.09+31.169	test-rmse:4210.38+37.9636
# [10]	train-rmse:3981.94+26.5386	test-rmse:3992.62+32.4986
# [11]	train-rmse:3795.14+24.5464	test-rmse:3807.41+29.0046
# [12]	train-rmse:3648.84+20.4424	test-rmse:3663.04+22.9869
# [13]	train-rmse:3515.26+14.8844	test-rmse:3530.83+13.8994
# [14]	train-rmse:3398+17.313	test-rmse:3415.22+15.1984
# [15]	train-rmse:3296.52+13.1907	test-rmse:3315.36+12.5546
# [16]	train-rmse:3212.2+13.2176	test-rmse:3232.82+11.6014
# [17]	train-rmse:3141.26+13.1802	test-rmse:3163.67+10.5928
# [18]	train-rmse:3083.31+13.932	test-rmse:3107.51+10.3248
# [19]	train-rmse:3035.81+16.3754	test-rmse:3061.53+13.2448
# [20]	train-rmse:2989.86+13.9176	test-rmse:3017.32+11.1512
# [21]	train-rmse:2953.88+10.8775	test-rmse:2983.16+7.6731
# [22]	train-rmse:2924.68+10.0311	test-rmse:2955.76+6.25717
# [23]	train-rmse:2901.19+10.7904	test-rmse:2933.95+7.54451
# [24]	train-rmse:2877.78+9.95972	test-rmse:2912.11+6.05934
# [25]	train-rmse:2857.6+8.21483	test-rmse:2893.37+5.46895
# [26]	train-rmse:2842.06+8.23096	test-rmse:2879.49+7.12938
# [27]	train-rmse:2826.04+7.31088	test-rmse:2865.05+5.87685
# [28]	train-rmse:2812.74+5.94708	test-rmse:2853.1+6.20477
# [29]	train-rmse:2802.11+6.23556	test-rmse:2844.06+7.59398
# [30]	train-rmse:2791.85+5.2508	test-rmse:2835.19+7.64658
# [31]	train-rmse:2783.24+4.52032	test-rmse:2828.28+7.59609
# [32]	train-rmse:2775.5+4.2446	test-rmse:2822.11+8.02997
# [33]	train-rmse:2767.76+4.26352	test-rmse:2815.66+7.88948
# [34]	train-rmse:2760.72+3.54581	test-rmse:2810.03+8.1065
# [35]	train-rmse:2754.81+3.08998	test-rmse:2805.53+7.64443
# [36]	train-rmse:2748.22+3.22308	test-rmse:2800.22+8.12599
# [37]	train-rmse:2742.38+3.32712	test-rmse:2795.92+7.34489
# [38]	train-rmse:2737.12+3.61614	test-rmse:2792.36+6.99972
# [39]	train-rmse:2732.15+3.63774	test-rmse:2788.77+6.57915
# [40]	train-rmse:2727.76+3.40543	test-rmse:2785.55+6.7824
# [41]	train-rmse:2723.34+3.24797	test-rmse:2782.15+7.16523
# [42]	train-rmse:2719.71+3.73727	test-rmse:2779.85+7.38439
# [43]	train-rmse:2716.18+3.61604	test-rmse:2777.63+7.80603
# [44]	train-rmse:2712.86+4.33273	test-rmse:2775.43+7.8218
# [45]	train-rmse:2709.4+3.85861	test-rmse:2773.1+7.91634
# [46]	train-rmse:2706.14+3.71133	test-rmse:2770.87+7.87926
# [47]	train-rmse:2702.86+3.47464	test-rmse:2768.84+7.96241
# [48]	train-rmse:2699.39+4.27461	test-rmse:2766.38+8.20608
# [49]	train-rmse:2695.98+4.8487	test-rmse:2764.17+8.11675
# test-rmse-mean     3560.452248
# test-rmse-std        13.899063
# train-rmse-mean    3526.343823
# train-rmse-std       11.777815
# dtype: float64 test-rmse-mean     1333.119370
# test-rmse-std        11.021599
# train-rmse-mean    1349.604910
# train-rmse-std       10.375317
# dtype: float64

# %%
print (train.shape, train[train.Marital_Status==0].shape)
# Out:
# (275035, 12) (162173, 12)

# %%
#fourth model
model_4_et = ExtraTreesRegressor(n_estimators=1450, max_depth=8,min_samples_split=10, min_samples_leaf=10, oob_score=True, n_jobs=6, random_state=123, verbose=1, bootstrap=True)
model_4_et.fit(input_w_tfidf[:train.shape[0],:], target[:train.shape[0]])
model_4_predict = model_4_et.predict(input_w_tfidf[train.shape[0]:,:])
submission.Purchase = model_4_predict
submission.to_csv(r"C:\Users\sk\AnacondaProjects\blackfriday5050\fourth_model.csv", index=False)
pickle.dump(model_4_et, open("model_4.pickle.dat", "wb"))
# Out:
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=6)]: Done 1450 out of 1450 | elapsed: 15.2min finished
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=6)]: Done 1450 out of 1450 | elapsed:   15.9s finished

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
temp=pd.read_csv('submission.csv')
temp_sample=temp['Purchase']
temp=pd.read_csv('first_model.csv')
temp_first=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_first)))
temp=pd.read_csv('second_model.csv')
temp_second=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_second)))
temp=pd.read_csv('third_model.csv')
temp_third=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_third)))
temp=pd.read_csv('fourth_model.csv')
temp_fourth=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_fourth)))
# Out:
# 2928.04386594
# 3165.41337039
# 2852.48558108
# 3137.5419754

# %%
import matplotlib.pyplot as plt
temp=pd.read_csv('submission.csv')
temp_first=pd.read_csv('first_model.csv')
x1=temp_first['User_ID'].astype(int)
plt.plot(x1[:100],temp_first['Purchase'][:100],color='red')
x=temp['User_ID'].astype(int)
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_second=pd.read_csv('second_model.csv')
x2=temp_second['User_ID'].astype(int)
plt.plot(x2[:100],temp_second['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_third=pd.read_csv('third_model.csv')
x3=temp_third['User_ID'].astype(int)
plt.plot(x3[:100],temp_third['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_fourth=pd.read_csv('fourth_model.csv')
x4=temp_fourth['User_ID'].astype(int)
plt.plot(x4[:100],temp_fourth['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()


#plotting all together
plt.plot(x1[:100],temp_first['Purchase'][:100],color='red',label='Model1')
plt.plot(x2[:100],temp_second['Purchase'][:100],color='green',label='Model2')
plt.plot(x3[:100],temp_third['Purchase'][:100],color='cyan',label='Model3')
plt.plot(x4[:100],temp_fourth['Purchase'][:100],color='black',label='Model4')
plt.plot(x[:100],temp['Purchase'][:100],color='blue',label='Original')
plt.legend(loc='best')
plt.xlabel('Users')
plt.ylabel('Purchase')
plt.show()
