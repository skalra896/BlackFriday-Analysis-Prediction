# %%
import numpy as np
import pandas as pd

# %%
input=pd.read_csv('input.csv')
input.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
# User_ID                       550068 non-null int64
# Product_ID                    550068 non-null object
# Gender                        550068 non-null object
# Age                           550068 non-null object
# Occupation                    550068 non-null int64
# City_Category                 550068 non-null object
# Stay_In_Current_City_Years    550068 non-null object
# Marital_Status                550068 non-null int64
# Product_Category_1            550068 non-null int64
# Product_Category_2            376430 non-null float64
# Product_Category_3            166821 non-null float64
# Purchase                      550068 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
train=input[:459062]
test=input[459062:]
train.info()
test.info()
train.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday1090\train.csv',index=False)
test.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday1090\test.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459062 entries, 0 to 459061
# Data columns (total 12 columns):
# User_ID                       459062 non-null int64
# Product_ID                    459062 non-null object
# Gender                        459062 non-null object
# Age                           459062 non-null object
# Occupation                    459062 non-null int64
# City_Category                 459062 non-null object
# Stay_In_Current_City_Years    459062 non-null object
# Marital_Status                459062 non-null int64
# Product_Category_1            459062 non-null int64
# Product_Category_2            316431 non-null float64
# Product_Category_3            140422 non-null float64
# Purchase                      459062 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 42.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91006 entries, 459062 to 550067
# Data columns (total 12 columns):
# User_ID                       91006 non-null int64
# Product_ID                    91006 non-null object
# Gender                        91006 non-null object
# Age                           91006 non-null object
# Occupation                    91006 non-null int64
# City_Category                 91006 non-null object
# Stay_In_Current_City_Years    91006 non-null object
# Marital_Status                91006 non-null int64
# Product_Category_1            91006 non-null int64
# Product_Category_2            59999 non-null float64
# Product_Category_3            26399 non-null float64
# Purchase                      91006 non-null int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 8.3+ MB

# %%
submission=input.loc[459062:,['User_ID','Product_ID','Purchase']]

# %%
submission.head()
submission.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday1090\submission.csv',index=False)

# %%
test.head()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 459062  1004633  P00350942      M   0-17           0             B
# 459063  1004633  P00092442      M   0-17           0             B
# 459064  1004633  P00142842      M   0-17           0             B
# 459065  1004634  P00295842      M  51-55          20             B
# 459066  1004634  P00110942      M  51-55          20             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 459062                          1               0                   3
# 459063                          1               0                   2
# 459064                          1               0                   2
# 459065                          1               1                   5
# 459066                          1               1                   1
#
#         Product_Category_2  Product_Category_3  Purchase
# 459062                 4.0                 5.0      5587
# 459063                 4.0                 NaN     16453
# 459064                 4.0                 8.0     16348
# 459065                 8.0                 NaN      7175
# 459066                 2.0                 NaN     19516

# %%
del(test['Purchase'])

# %%
test.head()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 459062  1004633  P00350942      M   0-17           0             B
# 459063  1004633  P00092442      M   0-17           0             B
# 459064  1004633  P00142842      M   0-17           0             B
# 459065  1004634  P00295842      M  51-55          20             B
# 459066  1004634  P00110942      M  51-55          20             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 459062                          1               0                   3
# 459063                          1               0                   2
# 459064                          1               0                   2
# 459065                          1               1                   5
# 459066                          1               1                   1
#
#         Product_Category_2  Product_Category_3
# 459062                 4.0                 5.0
# 459063                 4.0                 NaN
# 459064                 4.0                 8.0
# 459065                 8.0                 NaN
# 459066                 2.0                 NaN

# %%
test.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday1090\test.csv',index=False)

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
import seaborn as sns
sns.pairplot(train.dropna(),hue='Gender')

# %%
sns.pairplot(train.dropna(),hue='Age')

# %%
sns.pairplot(train.dropna())

# %%
frames=[train,test]
input=pd.concat(frames)
input.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday1090\input_total.csv',index=False)
print (input.shape)
input.head()
# Out:
# (550068, 12)
#     Age City_Category Gender  Marital_Status  Occupation  Product_Category_1  \
# 0  0-17             A      F               0          10                   3
# 1  0-17             A      F               0          10                   1
# 2  0-17             A      F               0          10                  12
# 3  0-17             A      F               0          10                  12
# 4   55+             C      M               0          16                   8
#
#    Product_Category_2  Product_Category_3 Product_ID  Purchase  \
# 0                 NaN                 NaN  P00069042    8370.0
# 1                 6.0                14.0  P00248942   15200.0
# 2                 NaN                 NaN  P00087842    1422.0
# 3                14.0                 NaN  P00085442    1057.0
# 4                 NaN                 NaN  P00285442    7969.0
#
#   Stay_In_Current_City_Years  User_ID
# 0                          2  1000001
# 1                          2  1000001
# 2                          2  1000001
# 3                          2  1000001
# 4                         4+  1000002

# %%
input.dtypes
# Out:
# Age                            object
# City_Category                  object
# Gender                         object
# Marital_Status                  int64
# Occupation                      int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Product_ID                     object
# Purchase                      float64
# Stay_In_Current_City_Years     object
# User_ID                         int64
# dtype: object

# %%
input.fillna(999,inplace=True)
input.head()
# Out:
#     Age City_Category Gender  Marital_Status  Occupation  Product_Category_1  \
# 0  0-17             A      F               0          10                   3
# 1  0-17             A      F               0          10                   1
# 2  0-17             A      F               0          10                  12
# 3  0-17             A      F               0          10                  12
# 4   55+             C      M               0          16                   8
#
#    Product_Category_2  Product_Category_3 Product_ID  Purchase  \
# 0               999.0               999.0  P00069042    8370.0
# 1                 6.0                14.0  P00248942   15200.0
# 2               999.0               999.0  P00087842    1422.0
# 3                14.0               999.0  P00085442    1057.0
# 4               999.0               999.0  P00285442    7969.0
#
#   Stay_In_Current_City_Years  User_ID
# 0                          2  1000001
# 1                          2  1000001
# 2                          2  1000001
# 3                          2  1000001
# 4                         4+  1000002

# %%
target=input.Purchase
target=np.array(target)
input.drop(['Purchase'],axis=1,inplace=True)

# %%
print(input.columns,input.dtypes)
# Out:
# Index(['Age', 'City_Category', 'Gender', 'Marital_Status', 'Occupation',
#        'Product_Category_1', 'Product_Category_2', 'Product_Category_3',
#        'Product_ID', 'Stay_In_Current_City_Years', 'User_ID'],
#       dtype='object') Age                            object
# City_Category                  object
# Gender                         object
# Marital_Status                  int64
# Occupation                      int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Product_ID                     object
# Stay_In_Current_City_Years     object
# User_ID                         int64
# dtype: object

# %%
input=input.applymap(str)
input.dtypes
# Out:
# Age                           object
# City_Category                 object
# Gender                        object
# Marital_Status                object
# Occupation                    object
# Product_Category_1            object
# Product_Category_2            object
# Product_Category_3            object
# Product_ID                    object
# Stay_In_Current_City_Years    object
# User_ID                       object
# dtype: object

# %%
input_pd=input.copy()

# %%
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer


from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn import linear_model

from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\sk\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
input=np.array(input)

for i in range(input.shape[1]):
    lbl=preprocessing.LabelEncoder()
    lbl.fit(list(input[:,i]))
    input[:,i]=lbl.transform(input[:,i])

# %%
print(input[4])
input=input.astype(int)
# Out:
# [6 2 1 0 8 18 17 15 2734 4 1]

# %%
#xgboost model
import xgboost as xgb
params={}
params['min_child_weight']=10
params['subsample']=0.7
params['colsample_bytree']=0.7
params['scale_pos_weight']=0.8
params['silent']=1                                                                                                                                        
params['max_depth']=6
params['nthread']=6
params['objective']='reg:linear'
params['eta']=0.1
params['base_score']=1800
params['eval_metric']='rmse'
params['seed']=0
plst=list(params.items())
num_rounds=300

# %%
import matplotlib.pyplot as plt
from xgboost import XGBClassifier, plot_importance
xgtrain=xgb.DMatrix(input[:train.shape[0],:],label=target[:train.shape[0]])
watchlist=[(xgtrain,'train')]
model_1_xgboost=xgb.train(plst,xgtrain,num_rounds)
plot_importance(model_1_xgboost)
plt.show()
'''print(model_1_xgboost.feature_importances_)
plt.bar(range(len(model_1_xgboost.feature_importances_)),model_1_xgboost.feature_importances_)
plt.show()'''
model_1_xgboost.get_score(importance_type='gain')
# Out:
# {'f0': 95783507.28227746,
#  'f1': 216730863.70215634,
#  'f10': 172154314.5323388,
#  'f2': 84781602.65357968,
#  'f3': 74766747.10216719,
#  'f4': 100222870.13209964,
#  'f5': 15486920770.45515,
#  'f6': 605541967.7616581,
#  'f7': 488772401.8939238,
#  'f8': 548647839.8479139,
#  'f9': 93567358.92462121}

# %%
import pickle
pickle.dump(model_1_xgboost, open("model_1_xgboost.pickle.dat", "wb"))

# %%
model_1_predict=model_1_xgboost.predict(xgb.DMatrix(input[train.shape[0]:,:]))
model_1_predict[model_1_predict<0]=25
submission.Purchase=model_1_predict
#submission.to_csv('../submission/submit_13.csv',index=False)
submission.to_csv(r'C:/Users/sk/AnacondaProjects/blackfriday1090/first_model.csv',index=False)

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8228.63+3.97228	test-rmse:8228.64+18.0521
# [1]	train-rmse:7518.26+3.48982	test-rmse:7518.31+17.5573
# [2]	train-rmse:6924.66+43.7401	test-rmse:6924.93+46.9917
# [3]	train-rmse:6397.61+65.9188	test-rmse:6397.49+58.1208
# [4]	train-rmse:5915.44+70.2299	test-rmse:5915.07+59.1165
# [5]	train-rmse:5508.23+86.8645	test-rmse:5507.7+78.8414
# [6]	train-rmse:5131.23+67.9601	test-rmse:5130.88+62.0183
# [7]	train-rmse:4802.77+56.6258	test-rmse:4802.77+53.4844
# [8]	train-rmse:4544.71+74.6236	test-rmse:4544.68+70.1034
# [9]	train-rmse:4283.94+63.9441	test-rmse:4284.23+59.7205
# [10]	train-rmse:4094.87+75.8287	test-rmse:4095.73+72.6046
# [11]	train-rmse:3922.78+90.5155	test-rmse:3923.83+86.6242
# [12]	train-rmse:3764.03+96.3187	test-rmse:3765.17+90.8028
# [13]	train-rmse:3617.84+81.5424	test-rmse:3619.17+76.2116
# [14]	train-rmse:3494.34+69.4476	test-rmse:3496.02+64.1385
# [15]	train-rmse:3399.99+59.9958	test-rmse:3402.22+55.2123
# [16]	train-rmse:3328.96+65.2564	test-rmse:3331.07+60.3674
# [17]	train-rmse:3259.45+49.5244	test-rmse:3261.86+44.6923
# [18]	train-rmse:3198.1+45.0631	test-rmse:3200.82+40.9375
# [19]	train-rmse:3151.18+41.0603	test-rmse:3153.98+37.074
# [20]	train-rmse:3103.74+34.2053	test-rmse:3106.79+30.4015
# [21]	train-rmse:3065.96+26.9582	test-rmse:3069.23+22.5784
# [22]	train-rmse:3034.54+22.4017	test-rmse:3037.92+18.2847
# [23]	train-rmse:3010.46+17.9432	test-rmse:3014.06+16.2999
# [24]	train-rmse:2992.15+21.2975	test-rmse:2995.83+20.4995
# [25]	train-rmse:2973.47+19.4853	test-rmse:2977.58+17.4705
# [26]	train-rmse:2960.25+20.0594	test-rmse:2964.66+19.8206
# [27]	train-rmse:2945.53+19.3904	test-rmse:2950.26+18.4386
# [28]	train-rmse:2932.72+19.3834	test-rmse:2937.7+17.4144
# [29]	train-rmse:2921.75+19.4468	test-rmse:2927.01+18.5156
# [30]	train-rmse:2910.56+15.6107	test-rmse:2916.11+15.8882
# [31]	train-rmse:2899.71+14.079	test-rmse:2905.45+13.3979
# [32]	train-rmse:2892.54+12.6086	test-rmse:2898.5+11.4925
# [33]	train-rmse:2884.82+12.2878	test-rmse:2890.97+12.4806
# [34]	train-rmse:2878.4+9.69752	test-rmse:2884.68+11.207
# [35]	train-rmse:2872.32+8.80425	test-rmse:2878.81+10.9126
# [36]	train-rmse:2867.29+8.81953	test-rmse:2873.94+10.5901
# [37]	train-rmse:2861.63+8.21547	test-rmse:2868.45+10.5611
# [38]	train-rmse:2856.28+7.9341	test-rmse:2863.19+11.3901
# [39]	train-rmse:2852.08+8.66896	test-rmse:2859.16+10.7224
# [40]	train-rmse:2848.33+8.45269	test-rmse:2855.62+11.0651
# [41]	train-rmse:2844.66+8.28429	test-rmse:2852.06+11.448
# [42]	train-rmse:2841.57+7.8908	test-rmse:2849.15+12.0262
# [43]	train-rmse:2838.61+7.66605	test-rmse:2846.35+12.6304
# [44]	train-rmse:2835.21+6.30375	test-rmse:2842.98+12.7506
# [45]	train-rmse:2831.54+5.91458	test-rmse:2839.49+12.492
# [46]	train-rmse:2827.66+6.41645	test-rmse:2835.79+11.7979
# [47]	train-rmse:2824.42+6.61787	test-rmse:2832.83+12.197
# [48]	train-rmse:2821.66+6.43162	test-rmse:2830.27+12.0522
# [49]	train-rmse:2819.13+6.77797	test-rmse:2827.97+12.5286
# test-rmse-mean     3634.747794
# test-rmse-std        31.840515
# train-rmse-mean    3630.719308
# train-rmse-std       32.199504
# dtype: float64 test-rmse-mean     1319.119228
# test-rmse-std        24.804738
# train-rmse-mean    1321.328649
# train-rmse-std       28.545331
# dtype: float64

# %%
#second model
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(input.astype(int))
tfidf
# Out:
# <550068x11 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5137016 stored elements in Compressed Sparse Row format>

# %%
input_tfidf=tfidf.toarray()

# %%
params = {}
params["min_child_weight"] = 10
params["subsample"] = 0.7
params["colsample_bytree"] = 0.7
params["scale_pos_weight"] = 0.8
params["silent"] = 1
params["max_depth"] = 12
params["nthread"] = 6
#params["gamma"] = 1
params["objective"] = "reg:linear"
params["eta"] = 0.1
params["base_score"] = 1800
params["eval_metric"] = "rmse"
params["seed"] = 0

plst = list(params.items())
num_rounds = 1800

# %%
xgtrain = xgb.DMatrix(input_tfidf[:train.shape[0],:], label=target[:train.shape[0]])
watchlist = [(xgtrain, 'train')]
model_1_xgboost = xgb.train(plst, xgtrain, num_rounds)

# %%
model_1_predict = model_1_xgboost.predict(xgb.DMatrix(input_tfidf[train.shape[0]:,:]))
model_1_predict[model_1_predict<0] = 25
submission.Purchase = model_1_predict
submission.to_csv(r'C:\Users\sk\AnacondaProjects\blackfriday1090\second_model.csv',index=False)
pickle.dump(model_1_xgboost, open("model_2.pickle.dat", "wb"))

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8280.43+4.4251	test-rmse:8282.76+18.3077
# [1]	train-rmse:7615.9+5.33724	test-rmse:7620.98+16.7493
# [2]	train-rmse:7055.58+32.2998	test-rmse:7063.96+36.1444
# [3]	train-rmse:6555.4+43.456	test-rmse:6568.1+38.2791
# [4]	train-rmse:6106.93+45.6053	test-rmse:6123.65+35.8257
# [5]	train-rmse:5728.62+53.8856	test-rmse:5750.57+46.0681
# [6]	train-rmse:5383.45+40.056	test-rmse:5410.72+34.5884
# [7]	train-rmse:5085.96+33.4995	test-rmse:5118.8+32.1143
# [8]	train-rmse:4845.37+44.5178	test-rmse:4884.34+41.2002
# [9]	train-rmse:4610.69+35.5629	test-rmse:4655.47+32.9153
# [10]	train-rmse:4431.37+42.6239	test-rmse:4483.95+43.8359
# [11]	train-rmse:4268.97+50.6966	test-rmse:4328.1+51.2172
# [12]	train-rmse:4122.91+58.0265	test-rmse:4188.29+55.7916
# [13]	train-rmse:3988.91+46.0283	test-rmse:4060.03+43.8538
# [14]	train-rmse:3875.76+38.2024	test-rmse:3952.43+35.895
# [15]	train-rmse:3784.68+34.005	test-rmse:3867.93+34.7245
# [16]	train-rmse:3710.5+36.2028	test-rmse:3800.77+36.3956
# [17]	train-rmse:3643.31+26.2147	test-rmse:3740.67+23.6176
# [18]	train-rmse:3583.02+20.8266	test-rmse:3685.91+20.9257
# [19]	train-rmse:3535.56+19.9949	test-rmse:3644.13+16.7356
# [20]	train-rmse:3487.66+13.7758	test-rmse:3601.89+8.30772
# [21]	train-rmse:3447.88+15.0819	test-rmse:3567.29+7.81709
# [22]	train-rmse:3415.22+14.8249	test-rmse:3539.98+8.21355
# [23]	train-rmse:3387.88+12.9046	test-rmse:3518.26+8.40258
# [24]	train-rmse:3360.72+6.82073	test-rmse:3496.07+6.75718
# [25]	train-rmse:3333.77+4.78935	test-rmse:3474.32+10.8051
# [26]	train-rmse:3316.63+5.50028	test-rmse:3462.58+12.1013
# [27]	train-rmse:3296.43+6.02386	test-rmse:3446.68+12.1868
# [28]	train-rmse:3277.51+3.17806	test-rmse:3432.46+13.7257
# [29]	train-rmse:3256.4+13.1735	test-rmse:3415.89+19.3595
# [30]	train-rmse:3241.54+11.8789	test-rmse:3404.86+16.0512
# [31]	train-rmse:3226.88+13.8828	test-rmse:3394.44+15.9606
# [32]	train-rmse:3213.9+15.7174	test-rmse:3385.69+13.5109
# [33]	train-rmse:3198.79+11.2293	test-rmse:3374.42+13.2507
# [34]	train-rmse:3186.38+12.8432	test-rmse:3366.7+14.7195
# [35]	train-rmse:3173.88+9.4707	test-rmse:3357.79+11.4079
# [36]	train-rmse:3165.27+12.0611	test-rmse:3352.31+11.4182
# [37]	train-rmse:3147.52+13.2246	test-rmse:3338.48+14.338
# [38]	train-rmse:3137.35+10.6481	test-rmse:3331.7+11.2713
# [39]	train-rmse:3124.85+11.8602	test-rmse:3323.01+15.1027
# [40]	train-rmse:3113.59+14.2587	test-rmse:3315.92+17.803
# [41]	train-rmse:3106.14+12.9208	test-rmse:3311.46+17.921
# [42]	train-rmse:3092.16+9.54033	test-rmse:3301.47+13.6728
# [43]	train-rmse:3084.97+9.56575	test-rmse:3297.49+13.6724
# [44]	train-rmse:3075.71+7.37659	test-rmse:3291.53+13.4993
# [45]	train-rmse:3065.06+11.0985	test-rmse:3283.99+17.1991
# [46]	train-rmse:3058.26+13.4306	test-rmse:3280.01+17.9092
# [47]	train-rmse:3050.88+15.404	test-rmse:3275.99+16.9237
# [48]	train-rmse:3040.06+13.2657	test-rmse:3268.56+17.2045
# [49]	train-rmse:3030.57+11.5611	test-rmse:3261.67+19.6
# test-rmse-mean     4054.089443
# test-rmse-std        22.105944
# train-rmse-mean    3926.543114
# train-rmse-std       20.975568
# dtype: float64 test-rmse-mean     1210.118989
# test-rmse-std        12.791775
# train-rmse-mean    1270.109996
# train-rmse-std       15.235878
# dtype: float64

# %%
#third model
input_w_tfidf=np.concatenate((input,input_tfidf),axis=1)

# %%
params = {}
params["min_child_weight"] = 10
params["subsample"] = 0.7
params["colsample_bytree"] = 0.7
params["scale_pos_weight"] = 0.8
params["silent"] = 1
params["max_depth"] = 8
params["nthread"] = 6
#params["gamma"] = 1
params["objective"] = "reg:linear"
params["eta"] = 0.1
params["base_score"] = 1800
params["eval_metric"] = "rmse"
params["seed"] = 0

plst = list(params.items())
num_rounds = 1750

xgtrain=xgb.DMatrix(input_w_tfidf[:train.shape[0],:],label=target[:train.shape[0]])
watchlist=[(xgtrain,'train')]
model_1_xgboost = xgb.train(plst, xgtrain, num_rounds)

model_1_predict = model_1_xgboost.predict(xgb.DMatrix(input_w_tfidf[train.shape[0]:,:]))
model_1_predict[model_1_predict<0] = 25
submission.Purchase = model_1_predict
submission.to_csv(r"C:\Users\sk\AnacondaProjects\blackfriday1090\third_model.csv", index=False)
pickle.dump(model_1_xgboost, open("model_3.pickle.dat", "wb"))

early_stopping=10
cv=xgb.cv(params,xgtrain,50,nfold=5,early_stopping_rounds=early_stopping, verbose_eval=1)
print(cv.mean(),cv.std())
# Out:
# [0]	train-rmse:8329.14+3.74166	test-rmse:8329.51+18.8529
# [1]	train-rmse:7621.78+33.2074	test-rmse:7622.64+46.6683
# [2]	train-rmse:6997.78+32.1199	test-rmse:6998.81+48.576
# [3]	train-rmse:6446.04+65.7424	test-rmse:6447.91+79.8744
# [4]	train-rmse:5943.01+52.041	test-rmse:5945.1+63.63
# [5]	train-rmse:5495.5+44.1551	test-rmse:5498.17+54.9002
# [6]	train-rmse:5101.64+40.1317	test-rmse:5105.17+49.4556
# [7]	train-rmse:4766.75+27.0503	test-rmse:4771.32+35.9453
# [8]	train-rmse:4499.67+35.4267	test-rmse:4505.14+43.9742
# [9]	train-rmse:4248.11+29.9322	test-rmse:4254.36+38.9273
# [10]	train-rmse:4046.25+39.644	test-rmse:4053.54+46.7549
# [11]	train-rmse:3852.68+36.9203	test-rmse:3860.65+42.7209
# [12]	train-rmse:3686.29+40.2403	test-rmse:3695.15+44.7297
# [13]	train-rmse:3548.51+46.0459	test-rmse:3558.78+51.3462
# [14]	train-rmse:3422.63+38.946	test-rmse:3434.01+44.1768
# [15]	train-rmse:3321+28.9908	test-rmse:3333.34+34.3142
# [16]	train-rmse:3239.73+30.188	test-rmse:3253.39+35.8072
# [17]	train-rmse:3161.35+24.9017	test-rmse:3175.99+30.5657
# [18]	train-rmse:3098.75+26.5906	test-rmse:3114.33+31.8601
# [19]	train-rmse:3048.45+25.531	test-rmse:3065.21+30.9095
# [20]	train-rmse:3004.15+21.0147	test-rmse:3021.89+26.7743
# [21]	train-rmse:2968.61+17.5965	test-rmse:2987.24+24.6736
# [22]	train-rmse:2937.19+15.3068	test-rmse:2956.81+23.4112
# [23]	train-rmse:2911.35+15.3742	test-rmse:2932.19+23.0246
# [24]	train-rmse:2889.36+14.7771	test-rmse:2911.35+22.8895
# [25]	train-rmse:2868.66+11.765	test-rmse:2891.86+19.8622
# [26]	train-rmse:2852.27+11.8521	test-rmse:2876.34+20.9822
# [27]	train-rmse:2835.61+9.11775	test-rmse:2860.63+18.7636
# [28]	train-rmse:2821.57+7.70415	test-rmse:2847.36+17.2715
# [29]	train-rmse:2810.44+6.24151	test-rmse:2837.27+15.5698
# [30]	train-rmse:2800.55+5.36601	test-rmse:2828.28+14.4493
# [31]	train-rmse:2791.91+4.91941	test-rmse:2820.52+14.0422
# [32]	train-rmse:2783.63+5.01126	test-rmse:2813.2+13.5037
# [33]	train-rmse:2776.92+4.99509	test-rmse:2807.43+13.9958
# [34]	train-rmse:2771.27+4.64712	test-rmse:2802.63+13.2765
# [35]	train-rmse:2763.74+4.90502	test-rmse:2796.1+13.679
# [36]	train-rmse:2758.03+4.17977	test-rmse:2791.37+13.6939
# [37]	train-rmse:2753.14+3.70216	test-rmse:2787.21+14.0183
# [38]	train-rmse:2748.22+3.37297	test-rmse:2783.07+14.1654
# [39]	train-rmse:2743.83+2.35668	test-rmse:2779.46+14.2243
# [40]	train-rmse:2739.72+1.84674	test-rmse:2776.27+14.2339
# [41]	train-rmse:2735.81+1.65356	test-rmse:2773.23+14.6364
# [42]	train-rmse:2732.19+1.72415	test-rmse:2770.57+14.5907
# [43]	train-rmse:2728.39+1.95516	test-rmse:2767.63+14.465
# [44]	train-rmse:2724.71+1.49367	test-rmse:2764.81+14.6326
# [45]	train-rmse:2720.95+1.07685	test-rmse:2761.66+14.7261
# [46]	train-rmse:2717.28+1.06879	test-rmse:2758.8+15.2653
# [47]	train-rmse:2713.96+1.42597	test-rmse:2756.36+15.7452
# [48]	train-rmse:2711.38+1.28962	test-rmse:2754.4+16.2779
# [49]	train-rmse:2706.61+1.92655	test-rmse:2750.41+16.6714
# test-rmse-mean     3575.777778
# test-rmse-std        27.550091
# train-rmse-mean    3553.930688
# train-rmse-std       17.824269
# dtype: float64 test-rmse-mean     1366.704820
# test-rmse-std        15.920878
# train-rmse-mean    1377.248970
# train-rmse-std       16.770113
# dtype: float64

# %%
print (train.shape, train[train.Marital_Status==0].shape)
# Out:
# (459062, 12) (271491, 12)

# %%
#fourth model
model_4_et = ExtraTreesRegressor(n_estimators=1450, max_depth=8,min_samples_split=10, min_samples_leaf=10, oob_score=True, n_jobs=6, random_state=123, verbose=1, bootstrap=True)
model_4_et.fit(input_w_tfidf[:train.shape[0],:], target[:train.shape[0]])
model_4_predict = model_4_et.predict(input_w_tfidf[train.shape[0]:,:])
submission.Purchase = model_4_predict
submission.to_csv(r"C:\Users\sk\AnacondaProjects\blackfriday1090\fourth_model.csv", index=False)
pickle.dump(model_4_et, open("model_4.pickle.dat", "wb"))
# Out:
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=6)]: Done 1450 out of 1450 | elapsed: 26.9min finished
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=6)]: Done 1450 out of 1450 | elapsed:    1.7s finished

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
temp=pd.read_csv('submission.csv')
temp_sample=temp['Purchase']
temp=pd.read_csv('first_model.csv')
temp_first=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_first)))
temp=pd.read_csv('second_model.csv')
temp_second=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_second)))
temp=pd.read_csv('third_model.csv')
temp_third=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_third)))
temp=pd.read_csv('fourth_model.csv')
temp_fourth=temp['Purchase']
print (np.sqrt(mean_squared_error(temp_sample, temp_fourth)))
# Out:
# 3374.62005982
# 3422.82221955
# 3378.09806381
# 3481.00510457

# %%
import matplotlib.pyplot as plt
temp=pd.read_csv('submission.csv')
temp_first=pd.read_csv('first_model.csv')
x1=temp_first['User_ID'].astype(int)
plt.plot(x1[:100],temp_first['Purchase'][:100],color='red')
x=temp['User_ID'].astype(int)
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_second=pd.read_csv('second_model.csv')
x2=temp_second['User_ID'].astype(int)
plt.plot(x2[:100],temp_second['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_third=pd.read_csv('third_model.csv')
x3=temp_third['User_ID'].astype(int)
plt.plot(x3[:100],temp_third['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()

temp_fourth=pd.read_csv('fourth_model.csv')
x4=temp_fourth['User_ID'].astype(int)
plt.plot(x4[:100],temp_fourth['Purchase'][:100],color='red')
plt.plot(x[:100],temp['Purchase'][:100],color='blue')
plt.show()


#plotting all together
plt.plot(x1[:100],temp_first['Purchase'][:100],color='red',label='Model1')
plt.plot(x2[:100],temp_second['Purchase'][:100],color='green',label='Model2')
plt.plot(x3[:100],temp_third['Purchase'][:100],color='cyan',label='Model3')
plt.plot(x4[:100],temp_fourth['Purchase'][:100],color='black',label='Model4')
plt.plot(x[:100],temp['Purchase'][:100],color='blue',label='Original')
plt.legend(loc='best')
plt.xlabel('Users')
plt.ylabel('Purchase')
plt.show()
